# %% [markdown]
# # Import Required Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Step 1: Data Collection

# %% [markdown]
# #### Load and inspect the data

# %%
import pandas as pd

# Load the dataset
url = 'booking_reviews_new2.csv'
data = pd.read_csv(url)  # Load

print("Columns in the dataset:")
print(data.columns)

# Display the first few rows of the DataFrame
print("\nFirst few rows of the dataset:")
print(data.head())
# Out:
# Columns in the dataset:
# Index(['Hotel_Address', 'Additional_Number_of_Scoring', 'Review_Date',
#        'Average_Score', 'Hotel_Name', 'Reviewer_Nationality',
#        'Negative_Review', 'Review_Total_Negative_Word_Counts',
#        'Total_Number_of_Reviews', 'Positive_Review',
#        'Review_Total_Positive_Word_Counts',
#        'Total_Number_of_Reviews_Reviewer_Has_Given', 'Reviewer_Score', 'Tags',
#        'days_since_review', 'lat', 'lng'],
#       dtype='object')
#
# First few rows of the dataset:
#                                        Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194    8/3/2017            7.7  Hotel Arena
# 1                           194    8/3/2017            7.7  Hotel Arena
# 2                           194   7/31/2017            7.7  Hotel Arena
# 3                           194   7/31/2017            7.7  Hotel Arena
# 4                           194   7/24/2017            7.7  Hotel Arena
#
#   Reviewer_Nationality                                    Negative_Review  \
# 0               Russia   I am so angry that i made this post available...
# 1              Ireland                                        No Negative
# 2            Australia   Rooms are nice but for elderly a bit difficul...
# 3       United Kingdom   My room was dirty and I was afraid to walk ba...
# 4          New Zealand   You When I booked with your company on line y...
#
#    Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 0                                397                     1403
# 1                                  0                     1403
# 2                                 42                     1403
# 3                                210                     1403
# 4                                140                     1403
#
#                                      Positive_Review  \
# 0   Only the park outside of the hotel was beauti...
# 1   No real complaints the hotel was great great ...
# 2   Location was good and staff were ok It is cut...
# 3   Great location in nice surroundings the bar a...
# 4    Amazing location and building Romantic setting
#
#    Review_Total_Positive_Word_Counts  \
# 0                                 11
# 1                                105
# 2                                 21
# 3                                 26
# 4                                  8
#
#    Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 0                                           7             2.9
# 1                                           7             7.5
# 2                                           9             7.1
# 3                                           1             3.8
# 4                                           3             6.7
#
#                                                 Tags days_since_review  \
# 0  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 1  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 2  [' Leisure trip ', ' Family with young childre...            3 days
# 3  [' Leisure trip ', ' Solo traveler ', ' Duplex...            3 days
# 4  [' Leisure trip ', ' Couple ', ' Suite ', ' St...           10 days
#
#          lat       lng
# 0  52.360576  4.915968
# 1  52.360576  4.915968
# 2  52.360576  4.915968
# 3  52.360576  4.915968
# 4  52.360576  4.915968

# %% [markdown]
# # Step 2: Data Cleaning and Preprocessing

# %%
# Remove duplicates
data.drop_duplicates(inplace=True)

# Handle missing values
data.fillna(method='ffill', inplace=True)

# Verify the data after cleaning
print("\nData after cleaning:")
print(data.info())
# Out:
# Data after cleaning:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Hotel_Address                               20000 non-null  object
#  1   Additional_Number_of_Scoring                20000 non-null  int64
#  2   Review_Date                                 20000 non-null  object
#  3   Average_Score                               20000 non-null  float64
#  4   Hotel_Name                                  20000 non-null  object
#  5   Reviewer_Nationality                        20000 non-null  object
#  6   Negative_Review                             20000 non-null  object
#  7   Review_Total_Negative_Word_Counts           20000 non-null  int64
#  8   Total_Number_of_Reviews                     20000 non-null  int64
#  9   Positive_Review                             20000 non-null  object
#  10  Review_Total_Positive_Word_Counts           20000 non-null  int64
#  11  Total_Number_of_Reviews_Reviewer_Has_Given  20000 non-null  int64
#  12  Reviewer_Score                              20000 non-null  float64
#  13  Tags                                        20000 non-null  object
#  14  days_since_review                           20000 non-null  object
#  15  lat                                         20000 non-null  float64
#  16  lng                                         20000 non-null  float64
# dtypes: float64(4), int64(5), object(8)
# memory usage: 2.7+ MB
# None

# %%
data.head()
# Out:
#                                        Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194    8/3/2017            7.7  Hotel Arena
# 1                           194    8/3/2017            7.7  Hotel Arena
# 2                           194   7/31/2017            7.7  Hotel Arena
# 3                           194   7/31/2017            7.7  Hotel Arena
# 4                           194   7/24/2017            7.7  Hotel Arena
#
#   Reviewer_Nationality                                    Negative_Review  \
# 0               Russia   I am so angry that i made this post available...
# 1              Ireland                                        No Negative
# 2            Australia   Rooms are nice but for elderly a bit difficul...
# 3       United Kingdom   My room was dirty and I was afraid to walk ba...
# 4          New Zealand   You When I booked with your company on line y...
#
#    Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 0                                397                     1403
# 1                                  0                     1403
# 2                                 42                     1403
# 3                                210                     1403
# 4                                140                     1403
#
#                                      Positive_Review  \
# 0   Only the park outside of the hotel was beauti...
# 1   No real complaints the hotel was great great ...
# 2   Location was good and staff were ok It is cut...
# 3   Great location in nice surroundings the bar a...
# 4    Amazing location and building Romantic setting
#
#    Review_Total_Positive_Word_Counts  \
# 0                                 11
# 1                                105
# 2                                 21
# 3                                 26
# 4                                  8
#
#    Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 0                                           7             2.9
# 1                                           7             7.5
# 2                                           9             7.1
# 3                                           1             3.8
# 4                                           3             6.7
#
#                                                 Tags days_since_review  \
# 0  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 1  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 2  [' Leisure trip ', ' Family with young childre...            3 days
# 3  [' Leisure trip ', ' Solo traveler ', ' Duplex...            3 days
# 4  [' Leisure trip ', ' Couple ', ' Suite ', ' St...           10 days
#
#          lat       lng
# 0  52.360576  4.915968
# 1  52.360576  4.915968
# 2  52.360576  4.915968
# 3  52.360576  4.915968
# 4  52.360576  4.915968

# %%
data.head()
# Out:
#                                        Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194    8/3/2017            7.7  Hotel Arena
# 1                           194    8/3/2017            7.7  Hotel Arena
# 2                           194   7/31/2017            7.7  Hotel Arena
# 3                           194   7/31/2017            7.7  Hotel Arena
# 4                           194   7/24/2017            7.7  Hotel Arena
#
#   Reviewer_Nationality                                    Negative_Review  \
# 0               Russia   I am so angry that i made this post available...
# 1              Ireland                                        No Negative
# 2            Australia   Rooms are nice but for elderly a bit difficul...
# 3       United Kingdom   My room was dirty and I was afraid to walk ba...
# 4          New Zealand   You When I booked with your company on line y...
#
#    Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 0                                397                     1403
# 1                                  0                     1403
# 2                                 42                     1403
# 3                                210                     1403
# 4                                140                     1403
#
#                                      Positive_Review  \
# 0   Only the park outside of the hotel was beauti...
# 1   No real complaints the hotel was great great ...
# 2   Location was good and staff were ok It is cut...
# 3   Great location in nice surroundings the bar a...
# 4    Amazing location and building Romantic setting
#
#    Review_Total_Positive_Word_Counts  \
# 0                                 11
# 1                                105
# 2                                 21
# 3                                 26
# 4                                  8
#
#    Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 0                                           7             2.9
# 1                                           7             7.5
# 2                                           9             7.1
# 3                                           1             3.8
# 4                                           3             6.7
#
#                                                 Tags days_since_review  \
# 0  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 1  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 2  [' Leisure trip ', ' Family with young childre...            3 days
# 3  [' Leisure trip ', ' Solo traveler ', ' Duplex...            3 days
# 4  [' Leisure trip ', ' Couple ', ' Suite ', ' St...           10 days
#
#          lat       lng
# 0  52.360576  4.915968
# 1  52.360576  4.915968
# 2  52.360576  4.915968
# 3  52.360576  4.915968
# 4  52.360576  4.915968

# %% [markdown]
# # Step 3: Exploratory Data Analysis (EDA)

# %%
rating_column = 'Reviewer_Score'  # Using the Reviewer_Score column for ratings
if rating_column in data.columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(data[rating_column])
    plt.title('Distribution of Ratings')
    plt.show()
else:
    print(f"Column '{rating_column}' not found. Please check the column names.")

# %% [markdown]
# # Step 4: Split the Dataset into Training and Testing Sets

# %%
train_data, test_data = train_test_split(data, test_size=0.3, random_state=42)
print("Training data shape:", train_data.shape)
print("Testing data shape:", test_data.shape)
# Out:
# Training data shape: (14000, 17)
# Testing data shape: (6000, 17)

# %% [markdown]
# # Step 5: Create User-Item Matrix for Training Data

# %%
# Create user-item matrix
rating_column = 'Reviewer_Score'
user_item_matrix_train = train_data.pivot_table(index='Reviewer_Nationality', columns='Hotel_Name', values=rating_column).fillna(0)

# %% [markdown]
# # Step 6: Model Building

# %% [markdown]
# ## 6.1 - Collaborative Filtering
# ### User-Based Collaborative Filtering

# %%
user_similarity_train = cosine_similarity(user_item_matrix_train)
user_similarity_df_train = pd.DataFrame(user_similarity_train, index=user_item_matrix_train.index, columns=user_item_matrix_train.index)

# %% [markdown]
# ### Item-Based Collaborative Filtering

# %%
# Compute cosine similarity between hotels
item_similarity_train = cosine_similarity(user_item_matrix_train.T)
item_similarity_df_train = pd.DataFrame(item_similarity_train, index=user_item_matrix_train.columns, columns=user_item_matrix_train.columns)

# %% [markdown]
# ## 6.2 - Content-Based Filtering
# Explanation
#
# TF-IDF Vectorizer: We use TfidfVectorizer to transform the combined features into a TF-IDF matrix.
# Content-Based Filtering using sparse matrices

# %%
train_data['combined_features'] = train_data['Hotel_Name'] + ' ' + train_data['Positive_Review'] + ' ' + train_data['Negative_Review']
tfidf = TfidfVectorizer()
tfidf_matrix_train = tfidf.fit_transform(train_data['combined_features'])

# Apply Truncated SVD to reduce dimensionality
n_components = 100  # Number of components to keep
svd = TruncatedSVD(n_components=n_components, random_state=42)
tfidf_matrix_reduced = svd.fit_transform(tfidf_matrix_train)

# Compute cosine similarity on the reduced matrix
content_similarity_train = cosine_similarity(tfidf_matrix_reduced)
content_similarity_df_train = pd.DataFrame(content_similarity_train, index=train_data['Hotel_Name'], columns=train_data['Hotel_Name'])

# %% [raw]
# Given the memory constraints, another effective approach to handle large datasets for content-based filtering is to use Truncated Singular Value Decomposition (SVD) to reduce the dimensionality of the TF-IDF matrix before computing cosine similarity. This approach can significantly reduce the memory requirements while preserving the important features of the data.
#
# Truncated SVD Approach
# Step-by-Step Approach
# Compute TF-IDF matrix
# Apply Truncated SVD to reduce dimensionality
# Compute cosine similarity on the reduced matrix

# %% [markdown]
# # Step 8: Define Recommendation Functions

# %%
content_similarity_df_train.head()
content_similarity_df_train['Intercontinental London The O2']
# Out:
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         1.000000
# Intercontinental London The O2                         0.223162
# Milestone Hotel Kensington                             0.207167
# Grange St Paul s Hotel                                 0.124650
# Gardette Park Hotel                                    0.162838
# ...                                                         ...
# Milestone Hotel Kensington                             0.293510
# Crowne Plaza London Kings Cross                        0.090341
# Park Plaza County Hall London                          0.199586
# K K Hotel George                                       0.120855
# Intercontinental London The O2                         0.344119
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.223162
# Intercontinental London The O2                         1.000000
# Milestone Hotel Kensington                            -0.028621
# Grange St Paul s Hotel                                 0.089079
# Gardette Park Hotel                                    0.312764
# ...                                                         ...
# Milestone Hotel Kensington                             0.228885
# Crowne Plaza London Kings Cross                        0.239292
# Park Plaza County Hall London                          0.398566
# K K Hotel George                                       0.052994
# Intercontinental London The O2                         0.344068
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.273673
# Intercontinental London The O2                         0.238252
# Milestone Hotel Kensington                            -0.037751
# Grange St Paul s Hotel                                 0.206826
# Gardette Park Hotel                                    0.188353
# ...                                                         ...
# Milestone Hotel Kensington                             0.041526
# Crowne Plaza London Kings Cross                        0.052454
# Park Plaza County Hall London                          0.141324
# K K Hotel George                                       0.076056
# Intercontinental London The O2                         0.225571
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.283434
# Intercontinental London The O2                         0.324616
# Milestone Hotel Kensington                             0.010865
# Grange St Paul s Hotel                                 0.069226
# Gardette Park Hotel                                    0.211648
# ...                                                         ...
# Milestone Hotel Kensington                             0.194361
# Crowne Plaza London Kings Cross                        0.097429
# Park Plaza County Hall London                          0.309574
# K K Hotel George                                       0.078357
# Intercontinental London The O2                         0.368917
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.194094
# Intercontinental London The O2                         0.386446
# Milestone Hotel Kensington                            -0.024517
# Grange St Paul s Hotel                                 0.042931
# Gardette Park Hotel                                    0.198372
# ...                                                         ...
# Milestone Hotel Kensington                             0.164565
# Crowne Plaza London Kings Cross                        0.394511
# Park Plaza County Hall London                          0.302122
# K K Hotel George                                       0.111070
# Intercontinental London The O2                         0.349556
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.214896
# Intercontinental London The O2                         0.314691
# Milestone Hotel Kensington                             0.012095
# Grange St Paul s Hotel                                 0.072920
# Gardette Park Hotel                                    0.125621
# ...                                                         ...
# Milestone Hotel Kensington                             0.072158
# Crowne Plaza London Kings Cross                        0.172782
# Park Plaza County Hall London                          0.296612
# K K Hotel George                                       0.070371
# Intercontinental London The O2                         0.244680
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.310097
# Intercontinental London The O2                         0.421146
# Milestone Hotel Kensington                             0.007294
# Grange St Paul s Hotel                                 0.040560
# Gardette Park Hotel                                    0.183054
# ...                                                         ...
# Milestone Hotel Kensington                             0.209647
# Crowne Plaza London Kings Cross                        0.275486
# Park Plaza County Hall London                          0.177892
# K K Hotel George                                       0.049932
# Intercontinental London The O2                         0.430465
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.342260
# Intercontinental London The O2                         0.391855
# Milestone Hotel Kensington                            -0.030223
# Grange St Paul s Hotel                                 0.162481
# Gardette Park Hotel                                    0.494565
# ...                                                         ...
# Milestone Hotel Kensington                             0.059746
# Crowne Plaza London Kings Cross                        0.129339
# Park Plaza County Hall London                          0.286142
# K K Hotel George                                       0.225757
# Intercontinental London The O2                         0.343648
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.301569
# Intercontinental London The O2                         0.568694
# Milestone Hotel Kensington                             0.041602
# Grange St Paul s Hotel                                 0.222063
# Gardette Park Hotel                                    0.327444
# ...                                                         ...
# Milestone Hotel Kensington                             0.295504
# Crowne Plaza London Kings Cross                        0.279025
# Park Plaza County Hall London                          0.497448
# K K Hotel George                                       0.160272
# Intercontinental London The O2                         0.505090
#
# Hotel_Name                       Intercontinental London The O2  ...  \
# Hotel_Name                                                       ...
# Intercontinental London The O2                         0.373092  ...
# Intercontinental London The O2                         0.347597  ...
# Milestone Hotel Kensington                             0.023554  ...
# Grange St Paul s Hotel                                 0.030465  ...
# Gardette Park Hotel                                    0.102393  ...
# ...                                                         ...  ...
# Milestone Hotel Kensington                             0.301167  ...
# Crowne Plaza London Kings Cross                        0.083590  ...
# Park Plaza County Hall London                          0.229993  ...
# K K Hotel George                                       0.052168  ...
# Intercontinental London The O2                         0.412490  ...
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.325280
# Intercontinental London The O2                         0.322071
# Milestone Hotel Kensington                            -0.003229
# Grange St Paul s Hotel                                 0.085228
# Gardette Park Hotel                                    0.217069
# ...                                                         ...
# Milestone Hotel Kensington                             0.250944
# Crowne Plaza London Kings Cross                        0.143187
# Park Plaza County Hall London                          0.420209
# K K Hotel George                                       0.154204
# Intercontinental London The O2                         0.420362
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.451244
# Intercontinental London The O2                         0.402310
# Milestone Hotel Kensington                             0.194613
# Grange St Paul s Hotel                                 0.109301
# Gardette Park Hotel                                    0.289707
# ...                                                         ...
# Milestone Hotel Kensington                             0.162077
# Crowne Plaza London Kings Cross                        0.086577
# Park Plaza County Hall London                          0.280803
# K K Hotel George                                       0.095004
# Intercontinental London The O2                         0.288182
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.391160
# Intercontinental London The O2                         0.260237
# Milestone Hotel Kensington                             0.193976
# Grange St Paul s Hotel                                 0.059157
# Gardette Park Hotel                                    0.149130
# ...                                                         ...
# Milestone Hotel Kensington                             0.286754
# Crowne Plaza London Kings Cross                        0.208051
# Park Plaza County Hall London                          0.237532
# K K Hotel George                                       0.087811
# Intercontinental London The O2                         0.496073
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.474303
# Intercontinental London The O2                         0.213123
# Milestone Hotel Kensington                             0.230604
# Grange St Paul s Hotel                                -0.000323
# Gardette Park Hotel                                    0.064451
# ...                                                         ...
# Milestone Hotel Kensington                             0.015590
# Crowne Plaza London Kings Cross                        0.069809
# Park Plaza County Hall London                          0.184225
# K K Hotel George                                       0.121557
# Intercontinental London The O2                         0.297449
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.452510
# Intercontinental London The O2                         0.241798
# Milestone Hotel Kensington                             0.151039
# Grange St Paul s Hotel                                 0.154511
# Gardette Park Hotel                                    0.322729
# ...                                                         ...
# Milestone Hotel Kensington                             0.162969
# Crowne Plaza London Kings Cross                        0.072411
# Park Plaza County Hall London                          0.179023
# K K Hotel George                                       0.307807
# Intercontinental London The O2                         0.294471
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.442565
# Intercontinental London The O2                         0.466113
# Milestone Hotel Kensington                            -0.001954
# Grange St Paul s Hotel                                -0.016934
# Gardette Park Hotel                                    0.150532
# ...                                                         ...
# Milestone Hotel Kensington                             0.088938
# Crowne Plaza London Kings Cross                        0.107001
# Park Plaza County Hall London                          0.258079
# K K Hotel George                                       0.084296
# Intercontinental London The O2                         0.441640
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.296178
# Intercontinental London The O2                         0.229437
# Milestone Hotel Kensington                             0.055486
# Grange St Paul s Hotel                                 0.083089
# Gardette Park Hotel                                    0.189450
# ...                                                         ...
# Milestone Hotel Kensington                             0.259886
# Crowne Plaza London Kings Cross                        0.051405
# Park Plaza County Hall London                          0.248810
# K K Hotel George                                       0.120290
# Intercontinental London The O2                         0.357335
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.245012
# Intercontinental London The O2                         0.213489
# Milestone Hotel Kensington                             0.000576
# Grange St Paul s Hotel                                 0.009593
# Gardette Park Hotel                                    0.148821
# ...                                                         ...
# Milestone Hotel Kensington                             0.144299
# Crowne Plaza London Kings Cross                        0.276198
# Park Plaza County Hall London                          0.111180
# K K Hotel George                                       0.073407
# Intercontinental London The O2                         0.219834
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.486070
# Intercontinental London The O2                         0.317070
# Milestone Hotel Kensington                             0.237939
# Grange St Paul s Hotel                                 0.020244
# Gardette Park Hotel                                    0.118372
# ...                                                         ...
# Milestone Hotel Kensington                             0.079480
# Crowne Plaza London Kings Cross                        0.091051
# Park Plaza County Hall London                          0.140618
# K K Hotel George                                       0.118237
# Intercontinental London The O2                         0.327248
#
# Hotel_Name                       Intercontinental London The O2
# Hotel_Name
# Intercontinental London The O2                         0.344119
# Intercontinental London The O2                         0.344068
# Milestone Hotel Kensington                             0.040933
# Grange St Paul s Hotel                                 0.123525
# Gardette Park Hotel                                    0.189903
# ...                                                         ...
# Milestone Hotel Kensington                             0.451335
# Crowne Plaza London Kings Cross                        0.138898
# Park Plaza County Hall London                          0.376091
# K K Hotel George                                       0.077292
# Intercontinental London The O2                         1.000000
#
# [14000 rows x 1801 columns]

# %%
content_similarity_df_train.loc[:,'Intercontinental London The O2']
# Out:
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         1.000000
# Intercontinental London The O2                         0.223162
# Milestone Hotel Kensington                             0.207167
# Grange St Paul s Hotel                                 0.124650
# Gardette Park Hotel                                    0.162838
# ...                                                         ...
# Milestone Hotel Kensington                             0.293510
# Crowne Plaza London Kings Cross                        0.090341
# Park Plaza County Hall London                          0.199586
# K K Hotel George                                       0.120855
# Intercontinental London The O2                         0.344119
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.223162
# Intercontinental London The O2                         1.000000
# Milestone Hotel Kensington                            -0.028621
# Grange St Paul s Hotel                                 0.089079
# Gardette Park Hotel                                    0.312764
# ...                                                         ...
# Milestone Hotel Kensington                             0.228885
# Crowne Plaza London Kings Cross                        0.239292
# Park Plaza County Hall London                          0.398566
# K K Hotel George                                       0.052994
# Intercontinental London The O2                         0.344068
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.273673
# Intercontinental London The O2                         0.238252
# Milestone Hotel Kensington                            -0.037751
# Grange St Paul s Hotel                                 0.206826
# Gardette Park Hotel                                    0.188353
# ...                                                         ...
# Milestone Hotel Kensington                             0.041526
# Crowne Plaza London Kings Cross                        0.052454
# Park Plaza County Hall London                          0.141324
# K K Hotel George                                       0.076056
# Intercontinental London The O2                         0.225571
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.283434
# Intercontinental London The O2                         0.324616
# Milestone Hotel Kensington                             0.010865
# Grange St Paul s Hotel                                 0.069226
# Gardette Park Hotel                                    0.211648
# ...                                                         ...
# Milestone Hotel Kensington                             0.194361
# Crowne Plaza London Kings Cross                        0.097429
# Park Plaza County Hall London                          0.309574
# K K Hotel George                                       0.078357
# Intercontinental London The O2                         0.368917
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.194094
# Intercontinental London The O2                         0.386446
# Milestone Hotel Kensington                            -0.024517
# Grange St Paul s Hotel                                 0.042931
# Gardette Park Hotel                                    0.198372
# ...                                                         ...
# Milestone Hotel Kensington                             0.164565
# Crowne Plaza London Kings Cross                        0.394511
# Park Plaza County Hall London                          0.302122
# K K Hotel George                                       0.111070
# Intercontinental London The O2                         0.349556
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.214896
# Intercontinental London The O2                         0.314691
# Milestone Hotel Kensington                             0.012095
# Grange St Paul s Hotel                                 0.072920
# Gardette Park Hotel                                    0.125621
# ...                                                         ...
# Milestone Hotel Kensington                             0.072158
# Crowne Plaza London Kings Cross                        0.172782
# Park Plaza County Hall London                          0.296612
# K K Hotel George                                       0.070371
# Intercontinental London The O2                         0.244680
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.310097
# Intercontinental London The O2                         0.421146
# Milestone Hotel Kensington                             0.007294
# Grange St Paul s Hotel                                 0.040560
# Gardette Park Hotel                                    0.183054
# ...                                                         ...
# Milestone Hotel Kensington                             0.209647
# Crowne Plaza London Kings Cross                        0.275486
# Park Plaza County Hall London                          0.177892
# K K Hotel George                                       0.049932
# Intercontinental London The O2                         0.430465
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.342260
# Intercontinental London The O2                         0.391855
# Milestone Hotel Kensington                            -0.030223
# Grange St Paul s Hotel                                 0.162481
# Gardette Park Hotel                                    0.494565
# ...                                                         ...
# Milestone Hotel Kensington                             0.059746
# Crowne Plaza London Kings Cross                        0.129339
# Park Plaza County Hall London                          0.286142
# K K Hotel George                                       0.225757
# Intercontinental London The O2                         0.343648
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.301569
# Intercontinental London The O2                         0.568694
# Milestone Hotel Kensington                             0.041602
# Grange St Paul s Hotel                                 0.222063
# Gardette Park Hotel                                    0.327444
# ...                                                         ...
# Milestone Hotel Kensington                             0.295504
# Crowne Plaza London Kings Cross                        0.279025
# Park Plaza County Hall London                          0.497448
# K K Hotel George                                       0.160272
# Intercontinental London The O2                         0.505090
#
# Hotel_Name                       Intercontinental London The O2  ...  \
# Hotel_Name                                                       ...
# Intercontinental London The O2                         0.373092  ...
# Intercontinental London The O2                         0.347597  ...
# Milestone Hotel Kensington                             0.023554  ...
# Grange St Paul s Hotel                                 0.030465  ...
# Gardette Park Hotel                                    0.102393  ...
# ...                                                         ...  ...
# Milestone Hotel Kensington                             0.301167  ...
# Crowne Plaza London Kings Cross                        0.083590  ...
# Park Plaza County Hall London                          0.229993  ...
# K K Hotel George                                       0.052168  ...
# Intercontinental London The O2                         0.412490  ...
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.325280
# Intercontinental London The O2                         0.322071
# Milestone Hotel Kensington                            -0.003229
# Grange St Paul s Hotel                                 0.085228
# Gardette Park Hotel                                    0.217069
# ...                                                         ...
# Milestone Hotel Kensington                             0.250944
# Crowne Plaza London Kings Cross                        0.143187
# Park Plaza County Hall London                          0.420209
# K K Hotel George                                       0.154204
# Intercontinental London The O2                         0.420362
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.451244
# Intercontinental London The O2                         0.402310
# Milestone Hotel Kensington                             0.194613
# Grange St Paul s Hotel                                 0.109301
# Gardette Park Hotel                                    0.289707
# ...                                                         ...
# Milestone Hotel Kensington                             0.162077
# Crowne Plaza London Kings Cross                        0.086577
# Park Plaza County Hall London                          0.280803
# K K Hotel George                                       0.095004
# Intercontinental London The O2                         0.288182
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.391160
# Intercontinental London The O2                         0.260237
# Milestone Hotel Kensington                             0.193976
# Grange St Paul s Hotel                                 0.059157
# Gardette Park Hotel                                    0.149130
# ...                                                         ...
# Milestone Hotel Kensington                             0.286754
# Crowne Plaza London Kings Cross                        0.208051
# Park Plaza County Hall London                          0.237532
# K K Hotel George                                       0.087811
# Intercontinental London The O2                         0.496073
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.474303
# Intercontinental London The O2                         0.213123
# Milestone Hotel Kensington                             0.230604
# Grange St Paul s Hotel                                -0.000323
# Gardette Park Hotel                                    0.064451
# ...                                                         ...
# Milestone Hotel Kensington                             0.015590
# Crowne Plaza London Kings Cross                        0.069809
# Park Plaza County Hall London                          0.184225
# K K Hotel George                                       0.121557
# Intercontinental London The O2                         0.297449
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.452510
# Intercontinental London The O2                         0.241798
# Milestone Hotel Kensington                             0.151039
# Grange St Paul s Hotel                                 0.154511
# Gardette Park Hotel                                    0.322729
# ...                                                         ...
# Milestone Hotel Kensington                             0.162969
# Crowne Plaza London Kings Cross                        0.072411
# Park Plaza County Hall London                          0.179023
# K K Hotel George                                       0.307807
# Intercontinental London The O2                         0.294471
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.442565
# Intercontinental London The O2                         0.466113
# Milestone Hotel Kensington                            -0.001954
# Grange St Paul s Hotel                                -0.016934
# Gardette Park Hotel                                    0.150532
# ...                                                         ...
# Milestone Hotel Kensington                             0.088938
# Crowne Plaza London Kings Cross                        0.107001
# Park Plaza County Hall London                          0.258079
# K K Hotel George                                       0.084296
# Intercontinental London The O2                         0.441640
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.296178
# Intercontinental London The O2                         0.229437
# Milestone Hotel Kensington                             0.055486
# Grange St Paul s Hotel                                 0.083089
# Gardette Park Hotel                                    0.189450
# ...                                                         ...
# Milestone Hotel Kensington                             0.259886
# Crowne Plaza London Kings Cross                        0.051405
# Park Plaza County Hall London                          0.248810
# K K Hotel George                                       0.120290
# Intercontinental London The O2                         0.357335
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.245012
# Intercontinental London The O2                         0.213489
# Milestone Hotel Kensington                             0.000576
# Grange St Paul s Hotel                                 0.009593
# Gardette Park Hotel                                    0.148821
# ...                                                         ...
# Milestone Hotel Kensington                             0.144299
# Crowne Plaza London Kings Cross                        0.276198
# Park Plaza County Hall London                          0.111180
# K K Hotel George                                       0.073407
# Intercontinental London The O2                         0.219834
#
# Hotel_Name                       Intercontinental London The O2  \
# Hotel_Name
# Intercontinental London The O2                         0.486070
# Intercontinental London The O2                         0.317070
# Milestone Hotel Kensington                             0.237939
# Grange St Paul s Hotel                                 0.020244
# Gardette Park Hotel                                    0.118372
# ...                                                         ...
# Milestone Hotel Kensington                             0.079480
# Crowne Plaza London Kings Cross                        0.091051
# Park Plaza County Hall London                          0.140618
# K K Hotel George                                       0.118237
# Intercontinental London The O2                         0.327248
#
# Hotel_Name                       Intercontinental London The O2
# Hotel_Name
# Intercontinental London The O2                         0.344119
# Intercontinental London The O2                         0.344068
# Milestone Hotel Kensington                             0.040933
# Grange St Paul s Hotel                                 0.123525
# Gardette Park Hotel                                    0.189903
# ...                                                         ...
# Milestone Hotel Kensington                             0.451335
# Crowne Plaza London Kings Cross                        0.138898
# Park Plaza County Hall London                          0.376091
# K K Hotel George                                       0.077292
# Intercontinental London The O2                         1.000000
#
# [14000 rows x 1801 columns]

# %%
similarity_series = content_similarity_df_train['Intercontinental London The O2']
# Exclude the hotel itself from the list
similarity_series = similarity_series[similarity_series.index != 'Intercontinental London The O2']
# Sort the similarity scores in descending order
similar_items = similarity_series.loc[:,'Intercontinental London The O2'].iloc[:,1].sort_values(ascending=False).head(10).index
similar_items
# Out:
# Index(['Haymarket Hotel', 'The Park Grand London Paddington',
#        'Haymarket Hotel', 'H tel Juliana Paris',
#        'Park Plaza County Hall London', 'The Principal London',
#        'The Park Grand London Paddington', 'Park Plaza County Hall London',
#        'Park Plaza County Hall London', 'Gardette Park Hotel'],
#       dtype='object', name='Hotel_Name')

# %%
def get_user_based_recommendations(user_id, top_n=10):
    similar_users = user_similarity_df_train.loc[user_id].sort_values(ascending=False).head(top_n+1).index[1:]
    recommendations = user_item_matrix_train.loc[similar_users].mean().sort_values(ascending=False).head(top_n)
    return list(recommendations.items())

def get_item_based_recommendations(hotel_name, top_n=10):
    similar_items = item_similarity_df_train.loc[hotel_name].sort_values(ascending=False).head(top_n+1).index[1:]
    recommendations = user_item_matrix_train[similar_items].mean().sort_values(ascending=False).head(top_n)
    return list(recommendations.items())
    
def get_content_based_recommendations(hotel_name, top_n=10):
    if hotel_name in content_similarity_df_train.index:
        similarity_series = content_similarity_df_train[hotel_name]
        # Exclude the hotel itself from the list
        similarity_series = similarity_series[similarity_series.index != hotel_name]
        # Sort the similarity scores in descending order
        similar_items = similarity_series.loc[:,hotel_name].iloc[:,1].sort_values(ascending=False).head(10).index
        l = []
        for i in similar_items:
            if i != hotel_name:
                l.append(i)
        
        recommendations = user_item_matrix_train[l].mean().sort_values(ascending=False).head(top_n)
        recommendations.items()
        return list(recommendations.items())
    else:
        return []

# %% [markdown]
# # Step 9: Evaluate the Models

# %% [markdown]
# #### Define Evaluation Function

# %%
def evaluate_model(model_func, id, ground_truth_ratings, top_n=10):
    recommendations = model_func(id, top_n)
    predicted_ratings = [rating for _, rating in recommendations]
    mse = mean_squared_error(ground_truth_ratings, predicted_ratings)
    return mse

# %% [markdown]
# #### Define Ground Truth Ratings

# %%
# Define ground truth ratings for evaluation (example values)
ground_truth_ratings = [4.5, 4.0, 4.5, 3.0, 5.0, 4.0, 4.0, 4.5, 4.0, 4.5]

# %% [markdown]
# ### Evaluate Models

# %%
get_content_based_recommendations('Intercontinental London The O2',10)
# Out:
# [('Park Plaza County Hall London', 4.654404269072611),
#  ('Park Plaza County Hall London', 4.654404269072611),
#  ('Park Plaza County Hall London', 4.654404269072611),
#  ('The Park Grand London Paddington', 4.482081125087193),
#  ('The Park Grand London Paddington', 4.482081125087193),
#  ('The Principal London', 3.288508402571927),
#  ('H tel Juliana Paris', 2.7591214896214895),
#  ('Gardette Park Hotel', 2.3246346153846154),
#  ('Haymarket Hotel', 1.4755850340136056),
#  ('Haymarket Hotel', 1.4755850340136056)]

# %%
actual_user_id = "Kuwait"
actual_hotel_name = "Park Plaza County Hall London"

for user_id in test_data['Reviewer_Nationality']:
    if user_id in user_item_matrix_train.index:
        actual_user_id = user_id
        break

for hotel_name in test_data['Hotel_Name']:
    if hotel_name in user_item_matrix_train.columns:
        actual_hotel_name = hotel_name
        break

if actual_user_id is None or actual_hotel_name is None:
    raise ValueError("Could not find a common user_id and hotel_name in both training and testing sets.")

# Evaluate User-Based Collaborative Filtering
user_based_mse = evaluate_model(get_user_based_recommendations, actual_user_id, ground_truth_ratings)

# Evaluate Item-Based Collaborative Filtering
item_based_mse = evaluate_model(get_item_based_recommendations, actual_hotel_name, ground_truth_ratings)

# Evaluate Content-Based Filtering
content_based_mse = evaluate_model(get_content_based_recommendations, actual_hotel_name, ground_truth_ratings)

# %% [markdown]
# #### Print the results

# %%
print(f'User-Based Collaborative Filtering MSE: {user_based_mse}')
print(f'Item-Based Collaborative Filtering MSE: {item_based_mse}')
print(f'Content-Based Filtering MSE: {content_based_mse}')
# Out:
# User-Based Collaborative Filtering MSE: 21.68914687911704
# Item-Based Collaborative Filtering MSE: 1.3433836425885466
# Content-Based Filtering MSE: 2.0168351059445055

# %%
import pickle

# Assume these variables have been defined and trained in the notebook
# user_similarity_df_train, item_similarity_df_train, content_similarity_df_train, user_item_matrix_train

# Save models and matrices
with open('user_similarity_df_train.pkl', 'wb') as f:
    pickle.dump(user_similarity_df_train, f)
with open('item_similarity_df_train.pkl', 'wb') as f:
    pickle.dump(item_similarity_df_train, f)
with open('content_similarity_df_train.pkl', 'wb') as f:
    pickle.dump(content_similarity_df_train, f)
with open('user_item_matrix_train.pkl', 'wb') as f:
    pickle.dump(user_item_matrix_train, f)
